# %% [markdown]
# <a href="https://colab.research.google.com/github/wbh-wkl/Numpy/blob/main/Numpy.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("wkl")
# Out:
# wkl

# %%
import matplotlib
import matplotlib.pyplot as plt

# %%
plt.plot([1, 2, 4, 9, 5, 3])
plt.show()
